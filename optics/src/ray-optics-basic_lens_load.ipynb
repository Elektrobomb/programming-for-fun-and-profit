# %%
# %matplotlib inline

# initialization
from rayoptics.environment import *

# %%
ed_optics_22989_lens_model = open_model("../data/codv_22989.seq")

# %%
layout_plt = plt.figure(FigureClass=InteractiveLayout, opt_model=ed_optics_22989_lens_model,
                        do_draw_rays=True, do_paraxial_layout=False).plot()
# Out:
# <InteractiveLayout size 640x480 with 1 Axes>
